# %% [markdown]
# # 01. Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import os
import folium
import json
from folium.plugins import MarkerCluster

# %%
# Create a path for easier importing
path = r'C:\Users\blim9\Desktop\Google Data Analytics\Case Study'

# %%
df = pd.read_csv(os.path.join (path, 'Data', 'Prepared Data', 'final_dataset.csv'))

# %%
# Ensuring we see the full Latitudes and Longitudes
pd.set_option('display.precision', 10)

# %% [markdown]
# # 02. Create the Folium map

# %%
df.head()
# Out:
#    Unnamed: 0           ride_id rideable_type member_type  \
# 0          30  DD06751C6019D865  classic_bike      annual
# 1          36  79973DC3B232048F  classic_bike      annual
# 2          72  F41EB054E44ACFDA  classic_bike      casual
# 3         121  B149E6C71A1C3B14  classic_bike      casual
# 4         123  C41829CD6CC5A8B6  classic_bike      casual
#
#        start_date_time        end_date_time  ride_length   month day_of_week  \
# 0  2021-08-08 17:21:26  2021-08-08 17:25:37        251.0  August      Sunday
# 1  2021-08-27 08:53:52  2021-08-27 09:18:29       1477.0  August      Friday
# 2  2021-08-12 16:52:09  2021-08-12 16:56:51        282.0  August    Thursday
# 3  2021-08-23 15:33:04  2021-08-23 16:09:00       2156.0  August      Monday
# 4  2021-08-23 10:11:09  2021-08-23 10:51:11       2402.0  August      Monday
#
#            start_station_name start_station_id            end_station_name  \
# 0   Desplaines St & Kinzie St     TA1306000003    Kingsbury St & Kinzie St
# 1  Larrabee St & Armitage Ave     TA1309000006       Michigan Ave & Oak St
# 2       Michigan Ave & Oak St            13042       Michigan Ave & Oak St
# 3       Michigan Ave & Oak St            13042       Michigan Ave & Oak St
# 4  Aberdeen St & Jackson Blvd            13157  Aberdeen St & Jackson Blvd
#
#   end_station_id  start_lat  start_long    end_lat   end_long
# 0   KA1503000043  41.888718  -87.644450  41.889175 -87.638504
# 1          13042  41.918083  -87.643745  41.900960 -87.623780
# 2          13042  41.900960  -87.623780  41.900960 -87.623780
# 3          13042  41.900960  -87.623780  41.900960 -87.623780
# 4          13157  41.877728  -87.654785  41.877728 -87.654785

# %%
# Drop the Unnamed: 0 column as it's not needed
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#             ride_id rideable_type member_type      start_date_time  \
# 0  DD06751C6019D865  classic_bike      annual  2021-08-08 17:21:26
# 1  79973DC3B232048F  classic_bike      annual  2021-08-27 08:53:52
# 2  F41EB054E44ACFDA  classic_bike      casual  2021-08-12 16:52:09
# 3  B149E6C71A1C3B14  classic_bike      casual  2021-08-23 15:33:04
# 4  C41829CD6CC5A8B6  classic_bike      casual  2021-08-23 10:11:09
#
#          end_date_time  ride_length   month day_of_week  \
# 0  2021-08-08 17:25:37        251.0  August      Sunday
# 1  2021-08-27 09:18:29       1477.0  August      Friday
# 2  2021-08-12 16:56:51        282.0  August    Thursday
# 3  2021-08-23 16:09:00       2156.0  August      Monday
# 4  2021-08-23 10:51:11       2402.0  August      Monday
#
#            start_station_name start_station_id            end_station_name  \
# 0   Desplaines St & Kinzie St     TA1306000003    Kingsbury St & Kinzie St
# 1  Larrabee St & Armitage Ave     TA1309000006       Michigan Ave & Oak St
# 2       Michigan Ave & Oak St            13042       Michigan Ave & Oak St
# 3       Michigan Ave & Oak St            13042       Michigan Ave & Oak St
# 4  Aberdeen St & Jackson Blvd            13157  Aberdeen St & Jackson Blvd
#
#   end_station_id  start_lat  start_long    end_lat   end_long
# 0   KA1503000043  41.888718  -87.644450  41.889175 -87.638504
# 1          13042  41.918083  -87.643745  41.900960 -87.623780
# 2          13042  41.900960  -87.623780  41.900960 -87.623780
# 3          13042  41.900960  -87.623780  41.900960 -87.623780
# 4          13157  41.877728  -87.654785  41.877728 -87.654785

# %%
# Create a column that only has the value 1. This will be used to add up how many times each station was used to begin a trip.
df['sum_col'] = 1

# %%
# Create a column that sums up the total of times each station a user began their trip at
df["num_of_station_starts"] = df.groupby("start_station_id")['sum_col'].transform("sum")

# %%
df['num_of_station_starts'].max()
# Out:
# 75996

# %%
df['num_of_station_starts'].dtype
# Out:
# dtype('int64')

# %%
df['num_of_station_starts'] = df['num_of_station_starts'].astype('int32')

# %%
# Create a new column turning it into a STR type for Folium to show numbers
df['num_of_station_starts_STR'] = df['num_of_station_starts'].astype('str')

# %%
df.head()
# Out:
#             ride_id rideable_type member_type      start_date_time  \
# 0  DD06751C6019D865  classic_bike      annual  2021-08-08 17:21:26
# 1  79973DC3B232048F  classic_bike      annual  2021-08-27 08:53:52
# 2  F41EB054E44ACFDA  classic_bike      casual  2021-08-12 16:52:09
# 3  B149E6C71A1C3B14  classic_bike      casual  2021-08-23 15:33:04
# 4  C41829CD6CC5A8B6  classic_bike      casual  2021-08-23 10:11:09
#
#          end_date_time  ride_length   month day_of_week  \
# 0  2021-08-08 17:25:37        251.0  August      Sunday
# 1  2021-08-27 09:18:29       1477.0  August      Friday
# 2  2021-08-12 16:56:51        282.0  August    Thursday
# 3  2021-08-23 16:09:00       2156.0  August      Monday
# 4  2021-08-23 10:51:11       2402.0  August      Monday
#
#            start_station_name start_station_id            end_station_name  \
# 0   Desplaines St & Kinzie St     TA1306000003    Kingsbury St & Kinzie St
# 1  Larrabee St & Armitage Ave     TA1309000006       Michigan Ave & Oak St
# 2       Michigan Ave & Oak St            13042       Michigan Ave & Oak St
# 3       Michigan Ave & Oak St            13042       Michigan Ave & Oak St
# 4  Aberdeen St & Jackson Blvd            13157  Aberdeen St & Jackson Blvd
#
#   end_station_id  start_lat  start_long    end_lat   end_long  sum_col  \
# 0   KA1503000043  41.888718  -87.644450  41.889175 -87.638504        1
# 1          13042  41.918083  -87.643745  41.900960 -87.623780        1
# 2          13042  41.900960  -87.623780  41.900960 -87.623780        1
# 3          13042  41.900960  -87.623780  41.900960 -87.623780        1
# 4          13157  41.877728  -87.654785  41.877728 -87.654785        1
#
#    num_of_station_starts num_of_station_starts_STR
# 0                  22527                     22527
# 1                  10194                     10194
# 2                  40648                     40648
# 3                  40648                     40648
# 4                  11436                     11436

# %%
df_subset = df.drop_duplicates(subset = ['start_station_id'])

# %%
df_subset.head()
# Out:
#             ride_id rideable_type member_type      start_date_time  \
# 0  DD06751C6019D865  classic_bike      annual  2021-08-08 17:21:26
# 1  79973DC3B232048F  classic_bike      annual  2021-08-27 08:53:52
# 2  F41EB054E44ACFDA  classic_bike      casual  2021-08-12 16:52:09
# 4  C41829CD6CC5A8B6  classic_bike      casual  2021-08-23 10:11:09
# 6  987AF38D6208B7E1  classic_bike      casual  2021-08-20 22:38:08
#
#          end_date_time  ride_length   month day_of_week  \
# 0  2021-08-08 17:25:37        251.0  August      Sunday
# 1  2021-08-27 09:18:29       1477.0  August      Friday
# 2  2021-08-12 16:56:51        282.0  August    Thursday
# 4  2021-08-23 10:51:11       2402.0  August      Monday
# 6  2021-08-20 23:32:13       3245.0  August      Friday
#
#            start_station_name start_station_id            end_station_name  \
# 0   Desplaines St & Kinzie St     TA1306000003    Kingsbury St & Kinzie St
# 1  Larrabee St & Armitage Ave     TA1309000006       Michigan Ave & Oak St
# 2       Michigan Ave & Oak St            13042       Michigan Ave & Oak St
# 4  Aberdeen St & Jackson Blvd            13157  Aberdeen St & Jackson Blvd
# 6        Wells St & Walton St     TA1306000011        Wells St & Walton St
#
#   end_station_id  start_lat  start_long    end_lat   end_long  sum_col  \
# 0   KA1503000043  41.888718  -87.644450  41.889175 -87.638504        1
# 1          13042  41.918083  -87.643745  41.900960 -87.623780        1
# 2          13042  41.900960  -87.623780  41.900960 -87.623780        1
# 4          13157  41.877728  -87.654785  41.877728 -87.654785        1
# 6   TA1306000011  41.899930  -87.634430  41.899930 -87.634430        1
#
#    num_of_station_starts num_of_station_starts_STR
# 0                  22527                     22527
# 1                  10194                     10194
# 2                  40648                     40648
# 4                  11436                     11436
# 6                   9541                      9541

# %%
m = folium.Map(location = [41.888718, -87.644450], tiles = 'OpenStreetMap', zoom_start=12)

markerCluster = MarkerCluster().add_to(m)

for i, row in df_subset.iterrows():
    lat = df_subset.at[i, 'start_lat']
    lng = df_subset.at[i, 'start_long']
    
    popup = 'Station : ' + str(df_subset.at[i, 'start_station_name']) + '<br>' + 'Uses : ' + df_subset.at[i, 'num_of_station_starts_STR']

    folium.Marker(location = [lat, lng], popup= popup, icon = folium.Icon(color='blue', icon='fire')).add_to(markerCluster)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_240e07bad85c35c6f972a865e8c4a216 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_240e07bad85c35c6f972a865e8c4a216&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_240e07bad85c35c6f972a865e8c4a216 = L.map(
#                 &quot;map_240e07bad85c35c6f972a865e8c4a216&quot;,
#                 {
#                     center: [41.888718, -87.64445],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a0f87842c3e2723973cd85e03b30eb8c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_240e07bad85c35c6f972a865e8c4a216);
#
#
#             var marker_cluster_50dfaede18718ac4bd59235314922bcd = L.markerClusterGroup(
#                 {}
#             );
#             map_240e07bad85c35c6f972a865e8c4a216.addLayer(marker_cluster_50dfaede18718ac4bd59235314922bcd);
#
#
#             var marker_2acb3a2883390e5cca785cbd09e71665 = L.marker(
#                 [41.888718, -87.64445],
#                 {}
#             ).addTo(marker_cluster_50dfaede18718ac4bd59235314922bcd);
#
#
#             var icon_28ff0e9fae063998c4b31cda4a9a1e27 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2acb3a2883390e5cca785cbd09e71665.setIcon(icon_28ff0e9fae063998c4b31cda4a9a1e27);
#
#
#         var popup_6fdc6d5b89960227a4fee8f346123c78 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0e2947ee981efb505ae9d06b07738410 = $(`&lt;div id=&quot;html_0e2947ee981efb505ae9d06b07738410&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station : Desplaines St &amp; Kinzie St&lt;br&gt;Uses : 22527&lt;/div&gt;`)[0];
#                 popup_6fdc6d5b89960227a4fee8f346123c78.setContent(html_0e2947ee981efb505ae9d06b07738410);
#
#
#
#         marker_2acb3a2883390e5cca785cbd09e71665.bindPopup(popup_6fdc6d5b89960227a4fee8f346123c78)
#         ;
#
#
#
#
#             var marker_e89976dad0e9512553026462e70c5344 = L.marker(
#                 [41.918083, -87.643745],
#                 {}
#             ).addTo(marker_cluster_50dfaede18718ac4bd59235314922bcd);
#
#
#             var icon_f5c9914e0629d60d534ecdfacfa4a598 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e89976dad0e9512553026462e70c5344.setIcon(icon_f5c9914e0629d60d534ecdfacfa4a598);
#
#
#         var popup_349877cf60c6f42d412503b5878c0266 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f6313cb119e2add942fd0f2e5bc9c4e6 = $(`&lt;div id=&quot;html_f6313cb119e2add942fd0f2e5bc9c4e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Station : Larrabee St &amp; Armitage Ave&lt;br&gt;Uses : 10194&lt;/div&gt;`)[0];
#                 popup_349877cf60c6f42d412503b5878c0266.setContent(html_f6313cb119e2add942fd0f2e5bc9c4e6);
#
#
#
#         marker_e89976dad0e9512553026462e70c5344.bindPopup(popup_349877cf60c6f42d412503b5878c0266)
#         ;
#
#
#
#
#             var marker_5ce44597a74ffbc07eba8de4deada949 = L.marker(
#                 [41.90096, -87.62378],
#                 {}
#             ).addTo(marker_cluster_50dfaede18718ac4bd59235314922bcd);
#
#
#             var icon_d7a7d56bafb553d3d71e1f701e4d20be = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fire&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5ce44597a74ffbc07eba8de4deada949.setIcon(icon_d7a7d56bafb553d3d71e1f701e4d20be);
#
#
#         var popup_5a38e727dd3961fc370ad06039f02633 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c470f98ebfd535ae9df463a380eaffd2 = $(`&lt;div id=&quot;html_c470f98ebfd535ae9df463a380eaffd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&

# %%
# Drop the num_of_start_stations_STR column as it's not needed anymore
df = df.drop(columns = ['num_of_station_starts_STR'])

# %%
df.head()
# Out:
#             ride_id rideable_type member_type      start_date_time  \
# 0  DD06751C6019D865  classic_bike      annual  2021-08-08 17:21:26
# 1  79973DC3B232048F  classic_bike      annual  2021-08-27 08:53:52
# 2  F41EB054E44ACFDA  classic_bike      casual  2021-08-12 16:52:09
# 3  B149E6C71A1C3B14  classic_bike      casual  2021-08-23 15:33:04
# 4  C41829CD6CC5A8B6  classic_bike      casual  2021-08-23 10:11:09
#
#          end_date_time  ride_length   month day_of_week  \
# 0  2021-08-08 17:25:37        251.0  August      Sunday
# 1  2021-08-27 09:18:29       1477.0  August      Friday
# 2  2021-08-12 16:56:51        282.0  August    Thursday
# 3  2021-08-23 16:09:00       2156.0  August      Monday
# 4  2021-08-23 10:51:11       2402.0  August      Monday
#
#            start_station_name start_station_id            end_station_name  \
# 0   Desplaines St & Kinzie St     TA1306000003    Kingsbury St & Kinzie St
# 1  Larrabee St & Armitage Ave     TA1309000006       Michigan Ave & Oak St
# 2       Michigan Ave & Oak St            13042       Michigan Ave & Oak St
# 3       Michigan Ave & Oak St            13042       Michigan Ave & Oak St
# 4  Aberdeen St & Jackson Blvd            13157  Aberdeen St & Jackson Blvd
#
#   end_station_id  start_lat  start_long    end_lat   end_long  sum_col  \
# 0   KA1503000043  41.888718  -87.644450  41.889175 -87.638504        1
# 1          13042  41.918083  -87.643745  41.900960 -87.623780        1
# 2          13042  41.900960  -87.623780  41.900960 -87.623780        1
# 3          13042  41.900960  -87.623780  41.900960 -87.623780        1
# 4          13157  41.877728  -87.654785  41.877728 -87.654785        1
#
#    num_of_station_starts
# 0                  22527
# 1                  10194
# 2                  40648
# 3                  40648
# 4                  11436

# %%
# Save the map as a HTML file
m.save('bike_station_map.html')

# %%
# Export the data set
df.to_csv(os.path.join (path, 'Data', 'Prepared Data', 'final_dataset_with_map.csv'))
